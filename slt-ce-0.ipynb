# %% [markdown]
# Please put your Legi number below. It will be deleted after grading.

# %%
Legi = 10-932-879

# %% [markdown]
# Grade:

# %% [markdown]
# # Coding exercise 0 (Test the submission system)

# %% [markdown]
# This is a test exercise, which is not graded.
# You can use it to test the submission process.
#
# Exercise: Answer the question below to modify the notebook.

# %% [markdown]
# What is the result of 1+1?
#
# Answer: 2
